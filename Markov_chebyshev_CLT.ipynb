# %% [markdown]
# # Lab 2
#
#
#
# *   Data and Sampling Distributions.
# *   Standard error. Markov, Chebyshev inequalities.
# *   CLT

# %% [markdown]
# 1) Suppose you are cooking porridge. To find out whether you have salted porridge or not, you do not need to eat all the porridge. Can you try just one spoon?
#
# Porridge - population, one spoon of a porridge - sample

# %% [markdown]
# 2) If we tried to conduct a study in order to identify the level of knowledge in the field of computer vision on 50 students of the DSAI track, then on what population do we collect our samples?
#
# *   students of the DSAI track
# *   men and women from 18 to 25
# *   students of Innopolis Universtiy

# %% [markdown]
# 3) If the sample size is large enough (more than 100), then such a sample is representative.
#
#
# *   Yes
# *   No
# *   Depends on the sampling method

# %% [markdown]
# Difference between descriptive and inferential statistics? (Sample statistics, population parametes)

# %% [markdown]
# ## I know the population distribution

# %%
import scipy.stats as stats
import math
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import expon

mu = 165           #sample mean
sigma = 15         #sample standard deviation
height = stats.norm(mu, sigma)
xs = np.linspace(135, 195, 100)
ys = height.pdf(xs)
plt.plot(xs, ys, linewidth=4)
plt.xlabel('height (cm)')
plt.ylabel('PDF')
# Out:
# Text(0, 0.5, 'PDF')

# %%
type(height)
# Out:
# scipy.stats._distn_infrastructure.rv_continuous_frozen

# %%
def make_sample(n=100):
    sample = height.rvs(n)
    return sample

# %%
number_of_elements = 100
sample = make_sample(number_of_elements)
sample
# Out:
# array([155.90392728, 174.8461138 , 186.87967076, 165.32367935,
#        152.9814552 , 192.48079354, 175.64071471, 154.30405523,
#        146.03382917, 157.10678034, 163.13456787, 151.84146878,
#        178.85280354, 132.40978255, 156.36891644, 160.07693219,
#        175.291399  , 156.52272192, 166.89995996, 158.85447919,
#        159.07777316, 127.99472091, 148.22989444, 148.13502787,
#        192.61581434, 159.69067835, 191.07108669, 138.29437004,
#        158.32892225, 169.68782553, 171.34545428, 154.92447119,
#        174.23896275, 118.20429899, 171.84098834, 166.81262944,
#        156.17802644, 171.9921273 , 180.56656542, 139.35261536,
#        165.0844102 , 164.94848966, 134.01675704, 170.84310109,
#        159.66124981, 164.36899836, 180.96980449, 157.39110248,
#        167.57731363, 132.63237536, 137.24742174, 177.34039652,
#        161.33302992, 165.27708395, 161.81662433, 158.85723386,
#        159.73661844, 168.07753881, 162.33257403, 179.25728675,
#        140.1938599 , 159.90864684, 129.16697765, 165.61759711,
#        155.64160107, 172.09556429, 168.7864634 , 169.67197261,
#        209.84007405, 161.33953474, 158.20322775, 182.51251443,
#        159.65955504, 158.6976713 , 146.45329804, 161.55161889,
#        155.26428779, 176.47160567, 171.96157034, 154.82843696,
#        149.7675061 , 148.97095835, 171.13789069, 162.81539434,
#        185.96997042, 147.64318687, 179.90466257, 163.68335738,
#        132.83896409, 169.05521445, 175.38868346, 139.72898687,
#        159.67414001, 172.43644109, 155.08213986, 151.54803603,
#        169.9102703 , 180.81188766, 154.38768194, 142.18995464])

# %%
sample.mean(), sample.std() #compare it with mu and sigma
# Out:
# (161.59917119379105, 15.484955360832828)

# %%
def sample_stat(sample):
    return sample.mean()

def compute_sampling_distribution(n=100, iters=1000):
    stats = [sample_stat(make_sample(n)) for i in range(iters)]
    return np.array(stats)

# %%
number_of_iterations = 1000
sample_means = compute_sampling_distribution(n=number_of_elements, iters=number_of_iterations)
sample_means
# Out:
# array([164.09458576, 166.16386574, 170.73166381, 162.59379967,
#        164.42864613, 163.25022271, 166.65088965, 165.93503165,
#        163.38288476, 166.37804359, 163.84149299, 165.60015189,
#        165.10946179, 163.86108928, 165.00845591, 164.57940258,
#        163.39975398, 162.90030332, 163.20938861, 163.98426934,
#        165.29624146, 163.22298134, 162.43929638, 166.36232111,
#        165.35201245, 166.22359271, 167.15685833, 164.3105398 ,
#        166.24991023, 164.63465096, 164.68477948, 162.80287904,
#        163.03227672, 165.75168809, 164.89739791, 165.00944005,
#        164.62594399, 166.63458325, 166.29951475, 164.63008947,
#        166.23237421, 166.69697905, 166.3529015 , 164.96659521,
#        167.00096559, 164.47194309, 164.09175502, 166.77428693,
#        167.08215635, 162.69417709, 167.02726357, 165.91423802,
#        165.82842343, 163.78836806, 162.96834675, 167.48989489,
#        166.03612505, 164.45735799, 163.65984096, 165.94727778,
#        162.24634477, 165.9793503 , 166.56180053, 164.70228579,
#        165.76034885, 163.10390692, 166.32385914, 162.90122352,
#        162.9227995 , 164.29607036, 163.50140663, 165.7808356 ,
#        164.26247101, 165.25177491, 165.33240521, 166.21742824,
#        166.55079828, 165.17467612, 163.43841274, 165.81251661,
#        162.2448121 , 165.15196171, 164.65036271, 166.01806803,
#        163.82689876, 166.13561188, 165.09745354, 165.02539833,
#        165.50635036, 165.30330852, 164.11818949, 163.81271008,
#        165.80631867, 166.94804587, 164.64582319, 164.14756041,
#        165.75131139, 164.49232875, 164.31300515, 164.9663253 ,
#        166.14276871, 164.79704154, 163.81530384, 166.30439538,
#        165.54638649, 164.86462416, 165.61678673, 163.66781608,
#        163.79942282, 167.10241637, 165.26477215, 164.56692918,
#        167.05210806, 164.5032597 , 165.82445097, 166.74768984,
#        167.14955738, 165.422958  , 163.6348315 , 162.7663581 ,
#        165.81884619, 166.7297881 , 166.00413506, 163.39039435,
#        165.64265271, 164.42166792, 163.71351675, 165.96519347,
#        164.94941622, 164.39260795, 164.46225826, 163.78057764,
#        167.89243042, 164.19232981, 165.2267731 , 165.70142905,
#        165.77410299, 164.77613914, 164.08403088, 163.18192157,
#        164.67506789, 165.24595719, 165.5661979 , 165.00691105,
#        162.73988615, 166.87546819, 164.5651358 , 166.36182912,
#        162.71277857, 166.09706795, 167.23923242, 164.45631838,
#        164.22610984, 164.93014299, 162.91546812, 167.11614305,
#        165.07066264, 166.3373942 , 167.92995132, 165.62897057,
#        167.95090963, 166.63809097, 165.3139416 , 167.11523912,
#        162.79324453, 165.93650895, 165.7389125 , 167.34603198,
#        163.17741207, 167.13913232, 164.52442289, 167.86852567,
#        165.01509412, 164.68384183, 163.41216028, 160.54398235,
#        164.92118759, 167.1264591 , 165.60886005, 164.20156267,
#        165.90065693, 164.6085378 , 164.97569645, 165.08280373,
#        163.825578  , 166.44448114, 166.74381831, 164.73154159,
#        166.17642689, 164.78998929, 165.16575873, 165.59826741,
#        163.11082903, 163.19806286, 166.26312299, 163.49915231,
#        163.76232892, 163.43466048, 163.1970331 , 164.54653706,
#        163.94876713, 161.67936045, 161.09093804, 167.98708065,
#        162.74445867, 167.08190851, 165.57701782, 164.38912477,
#        163.45178548, 165.9685796 , 166.61746194, 163.06397618,
#        166.10829813, 166.10695973, 166.66135349, 164.0797458 ,
#        163.59655587, 164.14527526, 164.09849228, 166.17946391,
#        167.19283847, 166.99413901, 166.81303401, 165.76900631,
#        166.24951717, 162.40167857, 163.87711683, 165.64889028,
#        167.03817662, 163.05498265, 166.0145791 , 164.39521635,
#        166.03805359, 165.34933204, 165.13282175, 166.66397974,
#        165.94464395, 165.59973158, 164.21720254, 163.76625068,
#        168.20810609, 164.35609824, 161.48307236, 165.10554335,
#        162.07848906, 163.73639692, 165.15967285, 164.35578318,
#        163.83820219, 164.57454463, 163.18118279, 167.412022  ,
#        165.90722747, 162.56693186, 163.04362187, 161.22242395,
#        165.20782691, 162.77098083, 165.1310459 , 165.51763723,
#        165.29913131, 165.49955798, 167.41462673, 164.62877282,
#        163.60507277, 166.96984968, 163.43245708, 166.96131824,
#        165.66960981, 162.25697852, 161.30206223, 165.68906326,
#        166.06497624, 161.42072774, 163.65623895, 164.81334963,
#        164.94887331, 164.7338981 , 162.67645176, 165.09649396,
#        167.20640715, 166.97958081, 164.96339267, 165.9745272 ,
#        165.23715205, 164.67508979, 162.82528285, 163.80929156,
#        165.50555314, 167.19312237, 163.64315634, 165.39664445,
#        161.3835337 , 164.88798625, 164.80989266, 161.14409229,
#        163.67274023, 165.0941523 , 165.44334175, 165.06474348,
#        164.09154045, 163.3919779 , 166.97335099, 164.80103946,
#        167.09133902, 166.2748228 , 162.24612313, 164.72884283,
#        166.20265363, 167.24562596, 166.93072675, 165.45620993,
#        164.44696145, 163.69433618, 164.02749287, 166.25030572,
#        163.98212914, 165.75120099, 165.00914255, 165.44456701,
#        163.70665174, 164.36128017, 167.79480086, 164.70914875,
#        167.31874133, 165.34269796, 163.72321815, 166.44588864,
#        165.48392372, 163.86205072, 166.58470623, 164.69243922,
#        165.87370057, 164.71782484, 163.94929853, 167.60760977,
#        166.47331957, 166.04056613, 166.30809438, 165.14129346,
#        168.53595895, 164.53444406, 165.25568502, 162.34207714,
#        165.63310104, 163.82220529, 166.45821349, 164.89283071,
#        164.53219849, 165.91474615, 163.11475611, 162.78826771,
#        164.76042758, 163.92173732, 167.82144756, 165.01592713,
#        165.44752746, 164.61815709, 166.34724698, 166.35091393,
#        166.13985446, 163.47620603, 165.1434593 , 163.26570872,
#        164.66888987, 164.63213569, 166.4679151 , 164.72776016,
#        166.38960091, 165.61963019, 164.24908888, 161.67880095,
#        163.90035116, 165.22293352, 164.11262415, 164.86002917,
#        165.27050057, 164.86927374, 165.25280074, 163.0713628 ,
#        165.43899117, 165.64289966, 166.30435768, 166.16440141,
#        164.83932334, 164.23297841, 162.69169093, 164.17367428,
#        163.51820733, 161.23532197, 165.52130508, 163.93990764,
#        162.97321995, 166.80555467, 166.35882658, 161.87170134,
#        166.67012501, 165.84464354, 165.09242905, 165.44019526,
#        166.18589485, 164.68547061, 169.04174897, 167.21951469,
#        163.10168886, 165.02462149, 168.10041377, 168.9177927 ,
#        163.27258369, 166.20646138, 166.45682858, 163.03407225,
#        166.58269444, 164.77024792, 163.98230535, 163.66371539,
#        169.844745  , 167.63959476, 163.90288022, 166.21402407,
#        165.85607826, 163.51999977, 165.11003839, 162.15613279,
#        163.86306342, 167.19314791, 163.09111083, 163.17110738,
#        166.71630962, 165.23127485, 165.35986071, 164.27002238,
#        166.61192462, 165.84832883, 163.74449384, 165.82251166,
#        166.45645092, 167.51987464, 161.69543631, 165.3898229 ,
#        167.03698317, 164.24418765, 163.44615647, 164.90949397,
#        163.93561543, 163.17510407, 164.05494956, 162.04984912,
#        161.78771498, 165.34793908, 164.65669441, 165.57059974,
#        167.97985337, 163.82358205, 164.22996828, 163.64732661,
#        164.46031796, 164.77368953, 166.13841333, 165.461453  ,
#        163.96633736, 163.96591143, 164.41177072, 164.26171868,
#        163.76020308, 164.99951087, 166.70320977, 162.04319083,
#        169.54807631, 164.93796822, 165.80790126, 166.24666777,
#        165.9263072 , 163.60099919, 164.71271735, 163.41632514,
#        165.2367247 , 164.91067476, 164.22173543, 162.45536702,
#        163.35272462, 163.06746932, 164.84098512, 164.73836458,
#        164.40235583, 166.36277684, 167.2812729 , 162.29890762,
#        165.34210352, 165.46896108, 163.82682825, 167.51283506,
#        164.02640061, 163.00947419, 165.7834275 , 164.82862029,
#        163.26027127, 164.25312645, 167.5422083 , 163.10278537,
#        162.43148351, 167.33301256, 166.26646686, 166.57713405,
#        165.92954187, 163.5080701 , 164.75797376, 163.703306  ,
#        164.00253797, 164.4852094 , 165.18126486, 167.74960328,
#        164.71247133, 163.00955269, 165.3367896 , 164.57935557,
#        166.62123819, 166.68239411, 165.6914002 , 163.24267786,
#        164.61852638, 165.47118568, 168.24034041, 165.09562627,
#        167.45048556, 166.69126167, 166.92775492, 165.48914739,
#        164.86402182, 165.07088005, 167.37811008, 164.25819228,
#        163.97929386, 163.19272794, 167.14781839, 161.98067685,
#        163.84567164, 167.61509605, 165.45831899, 165.59101363,
#        163.92550299, 165.77272058, 165.82886503, 165.97513285,
#        167.22797724, 167.09668647, 167.40699386, 167.12985461,
#        168.01783768, 166.10721373, 164.11234806, 164.29719792,
#        165.85993168, 166.87690646, 165.07263359, 166.76973016,
#        167.56755389, 166.04624032, 165.24445404, 164.61668338,
#        163.66480778, 166.78823053, 164.16505069, 164.75124743,
#        166.55998228, 161.82567859, 164.93350442, 165.6025444 ,
#        162.59851588, 167.24135639, 165.06317465, 163.67142334,
#        165.70879279, 163.86910035, 168.74236255, 165.96954852,
#        163.6104801 , 168.41343534, 166.19588754, 166.27614996,
#        163.64076191, 164.64761851, 165.06634449, 164.45551564,
#        164.20092614, 166.48238012, 165.73473682, 163.52217092,
#        162.90725487, 163.80698935, 165.60565413, 167.20958902,
#        164.27242212, 165.25007705, 161.03057286, 164.22209595,
#        166.0647315 , 166.72349358, 164.2854161 , 164.12635311,
#        164.08662376, 167.2999658 , 164.27032812, 163.69643879,
#        165.21013723, 169.55711418, 165.36961026, 167.09049617,
#        164.55349503, 162.87727563, 164.55639126, 165.35955301,
#        165.31264799, 165.04814345, 163.35961338, 164.04263158,
#        165.48718486, 166.35662513, 166.04057686, 165.36482422,
#        164.78414853, 163.60057309, 169.45247239, 165.04293086,
#        164.41311196, 164.67257167, 162.40543251, 164.47815663,
#        165.47771631, 166.9230849 , 166.72152405, 161.04478289,
#        166.55708356, 164.08527661, 164.05448355, 164.38829861,
#        166.4362735 , 167.70719535, 165.48201525, 166.28988394,
#        162.82402047, 164.51901618, 162.93118152, 163.43076883,
#        164.02001908, 165.09608129, 164.25959778, 164.55872138,
#        165.51960346, 165.18837214, 164.94723844, 163.33983085,
#        168.64469576, 166.37813983, 165.84706868, 164.32432504,
#        165.46701688, 164.58740653, 163.03885302, 162.20688486,
#        162.5596461 , 164.94617525, 166.72705505, 165.60640792,
#        161.82855895, 166.84194767, 162.59216096, 164.37719003,
#        165.56043603, 165.29114376, 164.91485237, 167.29341255,
#        166.13940139, 164.28017419, 166.79629272, 163.16845548,
#        166.72928239, 164.07116823, 166.58749083, 164.57923148,
#        163.57116494, 166.17989111, 164.43389265, 165.95458445,
#        166.14054236, 167.52051624, 165.83985764, 164.43082809,
#        165.88479383, 163.69727253, 164.73930519, 166.23526468,
#        164.56560875, 165.7290145 , 164.66643017, 164.91431042,
#        164.92144962, 160.9818694 , 166.55669059, 162.62411421,
#        160.45162067, 164.70444217, 164.16300185, 167.26709561,
#        164.93335351, 162.97630221, 166.5938618 , 166.53200549,
#        166.15735528, 165.61298474, 166.91213722, 163.4362839 ,
#        162.75881671, 165.52496812, 167.83543335, 165.96180765,
#        166.89482864, 164.57595185, 165.45403705, 166.14012229,
#        162.68605335, 165.60241364, 165.94041132, 166.52988261,
#        162.02623159, 164.62325999, 163.9399977 , 164.89162209,
#        166.1156457 , 164.99880238, 165.75887828, 164.02559904,
#        165.48490279, 163.53951385, 163.28695406, 164.56864844,
#        163.10470939, 164.60253612, 164.94870884, 165.29453877,
#        164.09352619, 165.73594471, 165.27729245, 167.56904883,
#        165.92318736, 167.38283861, 166.09946681, 162.51385564,
#        166.19123027, 167.6322913 , 165.11171777, 166.28936433,
#        162.21083987, 165.83466242, 166.5978338 , 165.66166151,
#        166.99407573, 166.72791938, 164.95065618, 165.28253094,
#        165.16872171, 164.12086533, 167.27973387, 166.0695464 ,
#        163.24331962, 164.31986887, 167.56324456, 165.6939848 ,
#        166.80770867, 164.15161804, 164.23788213, 165.44774695,
#        165.33411586, 165.51640733, 163.98868954, 165.23699274,
#        163.66109328, 165.55781079, 164.32065227, 164.65239768,
#        165.47138393, 164.35146   , 164.90589126, 163.27314829,
#        167.54899183, 164.66724002, 165.76148167, 167.02605751,
#        162.89487239, 166.88498216, 167.69997521, 163.25977632,
#        166.43585371, 162.56055751, 164.89097987, 165.58250164,
#        164.80625105, 166.79037136, 166.62660785, 165.06009193,
#        163.75947969, 166.98852818, 164.668419  , 162.80204497,
#        166.04752895, 166.09754255, 161.85803032, 164.33035143,
#        164.2016341 , 163.27082202, 164.94810665, 165.2516257 ,
#        167.64047959, 166.95339624, 164.50662349, 163.96750084,
#        165.1022679 , 164.60309913, 166.0477047 , 164.30728727,
#        167.88980894, 166.71591095, 164.35017716, 163.72894727,
#        163.09751645, 164.00182254, 164.68994681, 165.28043737,
#        164.61402916, 164.84986938, 163.48795472, 163.58767557,
#        164.29318241, 163.05149138, 167.05373307, 163.96202107,
#        164.15129929, 166.13341544, 165.30139673, 163.68451002,
#        163.38614055, 164.8775324 , 165.26860459, 164.45935172,
#        163.73875032, 166.68008004, 165.88584207, 164.65950533,
#        161.87035718, 163.87061169, 165.92833505, 166.17487814,
#        163.74756884, 165.7630389 , 164.1015463 , 164.5969057 ,
#        163.91307948, 165.40142003, 165.44972284, 168.56667102,
#        165.01551409, 166.02179287, 164.10191265, 164.66119797,
#        162.35847575, 166.56041214, 164.36465691, 161.59889906,
#        165.96926041, 164.57721357, 164.52592634, 166.09231867,
#        164.06759607, 165.84979323, 164.40648722, 165.74916396,
#        166.55673311, 166.98587037, 167.54041894, 163.35154967,
#        165.47647218, 166.17232739, 164.53306733, 163.23047336,
#        166.8439731 , 165.36243261, 166.25240519, 162.5418402 ,
#        166.10912738, 166.20250916, 165.73678534, 161.49406954,
#        162.97821153, 165.29480673, 164.06118032, 167.57328848,
#        167.15083568, 164.22032198, 166.76026881, 167.37372029,
#        166.64016631, 163.69732725, 168.88460702, 164.71084468,
#        164.94864692, 166.36323674, 165.32697198, 164.84585017,
#        163.04761538, 163.07744343, 166.69615688, 165.88743454,
#        163.03618048, 161.68492099, 165.1586347 , 166.29263463,
#        163.2619727 , 164.57486667, 165.70406045, 162.1451683 ,
#        166.11783897, 163.18769257, 163.32325576, 163.41260937,
#        165.07610124, 161.30547388, 165.38079444, 166.29690545,
#        165.2592684 , 163.1759419 , 166.60353374, 164.46725006,
#        166.15157455, 165.28121195, 166.42687381, 164.88903066,
#        165.12179908, 165.28581511, 164.90297759, 164.50742662,
#        167.69589168, 164.01534808, 165.12965369, 166.87606987,
#        165.1292578 , 165.21797942, 166.50121186, 165.88476361,
#        166.87528864, 165.30566965, 165.06366741, 166.82973272,
#        167.06950468, 165.89632218, 163.08613539, 165.81628742,
#        164.8115355 , 166.59041358, 162.6592283 , 166.56524742,
#        165.61987316, 164.95000069, 166.221169  , 167.53214794,
#        166.97953636, 166.48601495, 166.0827649 , 166.31311877,
#        166.84870996, 166.47694282, 163.80775952, 166.91559882,
#        164.69111825, 165.95710749, 165.32146665, 163.62826674,
#        164.18441223, 168.39587043, 165.2404503 , 166.88189344,
#        167.55352519, 164.96952101, 164.64288108, 167.14928656,
#        165.85832446, 165.50836671, 162.75162082, 164.35352182,
#        167.08756831, 163.89737537, 162.69666557, 162.78807774,
#        164.26121201, 163.00280041, 165.53655914, 166.22501703,
#        165.00418611, 167.95885475, 167.57025264, 165.2849631 ])

# %%
plt.hist(sample_means)
plt.xlabel('sample mean')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
sample_means.mean()
# Out:
# 165.06167863537905

# %% [markdown]
# This value is close to our population mean, but... Let us look to the precision in the experiments!

# %%
std_err = sample_means.std()
std_err
# Out:
# 1.5431032591831602

# %% [markdown]
# If we know the population distribution, but it is not normal...

# %%
unknown_stats = [sample_stat(expon.rvs(size=1000)) for i in range(number_of_iterations)] #sampling distribution from exponential samples
plt.hist(unknown_stats)
plt.xlabel('sample mean')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %% [markdown]
# We can use a sample to build a population model.

# %%
class Resampler(object):

    def __init__(self, sample): #stores the actual sample
        self.sample = sample
        self.n = len(sample)

    def resample(self): #generates a new sample by choosing from the original sample with replacement
        new_sample = np.random.choice(self.sample, self.n, replace=True)
        return new_sample

    def sample_stat(self, sample): #computes the sample statistics
        return sample.mean()

    def compute_sampling_distribution(self, iters=1000): #collects the statistics from the experiments
        # TODO: compute statistic for each resample
        resamples = [self.resample() for i in range(iters)]
        stats = [self.sample_stat(i) for i in resamples]
        return np.array(stats)

    def plot_sampling_distribution(self): #plots the sampling distribution
        sample_stats = self.compute_sampling_distribution()
        se = sample_stats.std()
        ci = np.percentile(sample_stats, [2.5, 97.5])

        plt.hist(sample_stats)
        plt.xlabel('sample statistic')
        plt.axvline(x=ci[0], color='red', label="2.5%")
        plt.text(ci[0] + 0.1, 0.1 * sample_stats.shape[0], "2.5%")
        plt.axvline(x=ci[1], color='red', label="97.5%")
        plt.text(ci[1] + 0.1, 0.1 * sample_stats.shape[0], "97.5%")
        plt.xlim(sample_stats.min() - sample_stats.std(), sample_stats.max() + sample_stats.std())
        plt.show()

# %% [markdown]
# ## I don't know two distributions ☹

# %%
female_mu = 160           #sample mean for females
female_sigma = 12         #sample standard deviation for females
female_height = stats.norm(female_mu, female_sigma)
female_xs = np.linspace(135, 195, 100)
female_ys = height.pdf(xs)
plt.plot(female_xs, female_ys, linewidth=4)
plt.xlabel('height of females (cm)')
plt.ylabel('PDF')
# Out:
# Text(0, 0.5, 'PDF')

# %%
male_mu = 174           #sample mean for male
male_sigma = 10         #sample standard deviation for male
male_height = stats.norm(male_mu, male_sigma)
male_xs = np.linspace(164, 195, 100)
male_ys = height.pdf(xs)
plt.plot(male_xs, male_ys, linewidth=4)
plt.xlabel('height of male (cm)')
plt.ylabel('PDF')
# Out:
# Text(0, 0.5, 'PDF')

# %%
male_height.mean() - female_height.mean()
# Out:
# 14.0

# %%
number_of_males_and_females = 100
female_sample = female_height.rvs(number_of_males_and_females)
male_sample = male_height.rvs(number_of_males_and_females)

# %%
male_sample.mean() - female_sample.mean()
# Out:
# 13.19069665595697

# %% [markdown]
# We will use [Cohen's d](https://en.wikipedia.org/wiki/Effect_size#Cohen's_d) to estimate the difference in heights:
#
# $d = \frac{\bar x_1 - \bar x_2}{s},$
#
# where $\bar x_1$ and $\bar x_2$ are sample means of males and females,
#
# $s = \sqrt{\frac{(n_1-1)s_1^2 + (n_2-1)s_2^2}{n_1 + n_2 - 2}}$ is a pooled standard deviation,
#
# $s_1$ and $s_2$ are sample standard deviations of males and females,
#
# $n_1$ and $n_2$ are the number of males and females in the samples.

# %%
def CohenEffectSize(group1, group2):
    diff = group1.mean() - group2.mean()
    n1, n2 = len(group1), len(group2)

    # By default ddof = 0 and we get a biased estimate of the variance
    var1 = group1.var(ddof=1)
    var2 = group2.var(ddof=1)

    # Note: in some papers/books "-2" in denominator might be ommited
    pooled_var = ((n1 - 1) * var1 + (n2 - 1) * var2) / (n1 + n2 - 2)
    d = diff / np.sqrt(pooled_var)
    return d, np.sqrt(pooled_var)

# %%
d, stddev = CohenEffectSize(male_sample, female_sample)
(d, stddev)
# Out:
# (1.2121779033285813, 10.88181579596193)

# %% [markdown]
# The difference in heights between males and females is approximately equal to 1 pooled standard deviation. According to the table below we observe a large or very large difference:
#
# | Effect size |  d   |
# |-------------|------|
# | Very small  | 0.01 |
# | Small       | 0.2  |
# | Medium      | 0.5  |
# | Large       | 0.8  |
# | Very large  | 1.2  |
# | Huge        | 2    |

# %%
d * stddev
# Out:
# 13.19069665595697

# %%
class CohenResampler(Resampler):
    def __init__(self, group1, group2):
        self.group1 = group1
        self.group2 = group2

    def resample(self):
        n, m = len(self.group1), len(self.group2)
        group1 = np.random.choice(self.group1, n, replace=True)
        group2 = np.random.choice(self.group2, m, replace=True)
        return group1, group2

    def sample_stat(self, groups):
        group1, group2 = groups
        return CohenEffectSize(group1, group2)[1]

# %%
resampler = CohenResampler(male_sample, female_sample)
resampler.plot_sampling_distribution()

# %% [markdown]
# ## Markov inequality

# %% [markdown]
# $$P(X \geq a) \leq \frac{E(X)}{a}$$

# %%
sample #sample of height that we've already generated
# Out:
# array([155.90392728, 174.8461138 , 186.87967076, 165.32367935,
#        152.9814552 , 192.48079354, 175.64071471, 154.30405523,
#        146.03382917, 157.10678034, 163.13456787, 151.84146878,
#        178.85280354, 132.40978255, 156.36891644, 160.07693219,
#        175.291399  , 156.52272192, 166.89995996, 158.85447919,
#        159.07777316, 127.99472091, 148.22989444, 148.13502787,
#        192.61581434, 159.69067835, 191.07108669, 138.29437004,
#        158.32892225, 169.68782553, 171.34545428, 154.92447119,
#        174.23896275, 118.20429899, 171.84098834, 166.81262944,
#        156.17802644, 171.9921273 , 180.56656542, 139.35261536,
#        165.0844102 , 164.94848966, 134.01675704, 170.84310109,
#        159.66124981, 164.36899836, 180.96980449, 157.39110248,
#        167.57731363, 132.63237536, 137.24742174, 177.34039652,
#        161.33302992, 165.27708395, 161.81662433, 158.85723386,
#        159.73661844, 168.07753881, 162.33257403, 179.25728675,
#        140.1938599 , 159.90864684, 129.16697765, 165.61759711,
#        155.64160107, 172.09556429, 168.7864634 , 169.67197261,
#        209.84007405, 161.33953474, 158.20322775, 182.51251443,
#        159.65955504, 158.6976713 , 146.45329804, 161.55161889,
#        155.26428779, 176.47160567, 171.96157034, 154.82843696,
#        149.7675061 , 148.97095835, 171.13789069, 162.81539434,
#        185.96997042, 147.64318687, 179.90466257, 163.68335738,
#        132.83896409, 169.05521445, 175.38868346, 139.72898687,
#        159.67414001, 172.43644109, 155.08213986, 151.54803603,
#        169.9102703 , 180.81188766, 154.38768194, 142.18995464])

# %% [markdown]
# Markov inequality gives us the upper bound for the probabilities:

# %%
x = range(120,300)
y = []
ls = np.linspace(120, 300,180)
y4 = 1-height.cdf(ls)
for a in x:
  y.append(sample.mean()/a)
plt.plot(x, y, label=r"$\frac{EX}{a}$")
y2 = [1 for i in range(120,300)]
y3 = [sum(i >= index for i in sample)/len(sample) for index in x]
# TODO: plot an exact P(X >= a)

plt.plot(x,y2,label = 'max probability')
plt.plot(x,y3,label = 'probability(counting)')
plt.plot(ls,y4,label = 'exactt probability (cdf)')

plt.xlabel('given value (cm)')
plt.ylabel('probability') #probability of the height being greated than the given value
plt.legend(loc = "upper right",fontsize = 'small')
plt.show()

# %% [markdown]
# ## Chebyshev inequality

# %% [markdown]
# $$P(|X-\mu|\geq k\sigma)≤\frac{1}{k^2}$$

# %%
k = range(1,10)
for i in k:
  print('P(|X-𝜇| >= {}𝜎) <= {}'.format(i, 1/(i*i)))
# Out:
# P(|X-𝜇| >= 1𝜎) <= 1.0
# P(|X-𝜇| >= 2𝜎) <= 0.25
# P(|X-𝜇| >= 3𝜎) <= 0.1111111111111111
# P(|X-𝜇| >= 4𝜎) <= 0.0625
# P(|X-𝜇| >= 5𝜎) <= 0.04
# P(|X-𝜇| >= 6𝜎) <= 0.027777777777777776
# P(|X-𝜇| >= 7𝜎) <= 0.02040816326530612
# P(|X-𝜇| >= 8𝜎) <= 0.015625
# P(|X-𝜇| >= 9𝜎) <= 0.012345679012345678

# %% [markdown]
# $$P(|X-\mu|\leq k\sigma)\geq 1 - \frac{1}{k^2}$$

# %%
k = range(1,10)
for i in k:
  print('P(|X-𝜇| <= {}𝜎) >= {}'.format(i, 1-(1/(i*i))))
# Out:
# P(|X-𝜇| <= 1𝜎) >= 0.0
# P(|X-𝜇| <= 2𝜎) >= 0.75
# P(|X-𝜇| <= 3𝜎) >= 0.8888888888888888
# P(|X-𝜇| <= 4𝜎) >= 0.9375
# P(|X-𝜇| <= 5𝜎) >= 0.96
# P(|X-𝜇| <= 6𝜎) >= 0.9722222222222222
# P(|X-𝜇| <= 7𝜎) >= 0.9795918367346939
# P(|X-𝜇| <= 8𝜎) >= 0.984375
# P(|X-𝜇| <= 9𝜎) >= 0.9876543209876543

# %% [markdown]
# Example, this means that at least 75\% of your data lies between $\mu-2\sigma$ and $\mu+2\sigma$. The inequality works for any distribution!!!

# %% [markdown]
# ## Law of large numbers

# %% [markdown]
# $$\lim_{n \rightarrow ∞} P(|\bar{X} - \mu | \geq ϵ)=0, $$
#
# $$\lim_{n \rightarrow ∞} P(|\bar{X} - \mu | < ϵ)=1 $$

# %%
height_samples = [make_sample(i).mean() for i in range(1,1000)]
plt.plot(range(1,1000), height_samples)
plt.xlabel('number of experiments')
plt.ylabel('probability')
plt.ylim([150, 180])
plt.xlim([1, 1000])
plt.show()

# %% [markdown]
# ## The resources
#
# [Inferetntial statistics](https://github.com/AllenDowney/CompStats/blob/master/sampling_soln.ipynb)
#
# [Pandas recap](https://github.com/tdpetrou/Learn-Pandas/blob/master/Selecting%20Subsets/01%20Selecting%20Subsets%20with%20%5B%20%5D%2C%20.loc%20and%20.iloc.ipynb)
#
# [How NOT to do the indexing](https://github.com/tdpetrou/Learn-Pandas/blob/64b4795b393960df110c47f697bb7f77777f3e7c/Selecting%20Subsets/04%20How%20NOT%20to%20select%20subsets%20of%20data.ipynb)
